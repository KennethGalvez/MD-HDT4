# %% [markdown]
# ## Usando sépalo

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from kneed import KneeLocator

# Leer el archivo CSV y seleccionar dos columnas específicas
data = pd.read_csv('iris.csv', usecols=['sepal_length', 'sepal_width'])

# Convertir los datos a un arreglo de numpy
X = data.values

# Estandarizar los datos
scaler = StandardScaler()
X = scaler.fit_transform(X)

# Calcular la inercia para múltiples valores de n_clusters
inertias = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, random_state=0)
    kmeans.fit(X)
    inertias.append(kmeans.inertia_)

# Utilizar la función KneeLocator para encontrar el codo
kn = KneeLocator(range(1, 11), inertias, curve='convex', direction='decreasing')
n_clusters = kn.knee

# Graficar la curva de la inercia y el codo encontrado
plt.plot(range(1, 11), inertias, marker='o')
plt.axvline(x=n_clusters, linestyle='--', color='r', label='Codo')
plt.xlabel('Número de Clusters')
plt.ylabel('Inercia')
plt.legend()
plt.show()
# Out:
# C:\Users\rebec\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rebec\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rebec\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
# ...

# %% [markdown]
# ## Usando pétalo

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from kneed import KneeLocator

# Leer el archivo CSV y seleccionar dos columnas específicas
data = pd.read_csv('iris.csv', usecols=['petal_length', 'petal_width'])

# Convertir los datos a un arreglo de numpy
X = data.values

# Estandarizar los datos
scaler = StandardScaler()
X = scaler.fit_transform(X)

# Calcular la inercia para múltiples valores de n_clusters
inertias = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, random_state=0)
    kmeans.fit(X)
    inertias.append(kmeans.inertia_)

# Utilizar la función KneeLocator para encontrar el codo
kn = KneeLocator(range(1, 11), inertias, curve='convex', direction='decreasing')
n_clusters = kn.knee

# Graficar la curva de la inercia y el codo encontrado
plt.plot(range(1, 11), inertias, marker='o')
plt.axvline(x=n_clusters, linestyle='--', color='r', label='Codo')
plt.xlabel('Número de Clusters')
plt.ylabel('Inercia')
plt.legend()
plt.show()
# Out:
# C:\Users\rebec\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rebec\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rebec\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
# ...

# %% [markdown]
# ## Conclusiones
#
# Las conclusiones a las que llegamos es que al hacerlas manuales, ambas graficas de codo quedaron muy parecidas a las creadas con "kneed".
# No encontramos una diferencia entre las graficas que creamos y las que creo "kneed"
#
# "Kneed" si nos dio el numero correcto de clusters (3) el cual se puede notar en las graficas de arriba.
